# %% [markdown]
# # Web Scraping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "http://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
#response.content

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#soup

# %%
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p

# %%
#soup.select('#chart-position-1')

# %%
soup.cite['class']
# Out:
# ['title']

# %%
#soup.select('.title')

# %%
# for item in soup.select('.title'):
#     print(item.get_text())

# %%
# for item in soup.select('.artist'):
#     print(item.get_text())

# %% [markdown]
# ## Creating DataFrame for first 100 songs

# %%
title = []
artist = []


    
tlist = soup.select('.title')
alist = soup.select('.artist')


num_iter = len(soup.select(".title"))

for i in range(num_iter):
    title.append(tlist[i].get_text())
    artist.append(alist[i].get_text())

# %%
# title

# %%
song_df = pd.DataFrame({'song':title, 'artist':artist})

# %%
song_df
# Out:
#                  song                      artist
# 0              Unholy      Sam Smith & Kim Petras
# 1     I'm Good (Blue)   David Guetta & Bebe Rexha
# 2           Thank God  Kane Brown & Katelyn Brown
# 3       Face It Alone                       Queen
# 4   wait in the truck       HARDY & Lainey Wilson
# ..                ...                         ...
# 95         Country On                  Luke Bryan
# 96   Everything I Own                       Bread
# 97          I See Red   Everybody Loves an Outlaw
# 98  Betty (Get Money)                  Yung Gravy
# 99        golden hour                        JVKE
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Adding top songs from 1989 to DataFrame

# %%
url2 = "https://digitaldreamdoor.com/pages/bg_hits/bg_hits_89.html"

# %%
response2 = requests.get(url2)
response2.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response2.content, "html.parser")

# %%
soup2.select('body > table > tbody > tr:nth-child(2) > td > table > tbody > tr:nth-child(4) > td > table > tbody > tr:nth-child(2)')
# Out:
# [<tr>
#  <td class="s1">1</td>
#  <td class="s2">Fight The Power
#  </td><td class="s3">Public Enemy
#  </td></tr>]

# %%
title2 = []
artist2 = []


    
tlist2 = soup2.select('.s2')
alist2 = soup2.select('.s3')


num_iter2 = len(soup2.select(".s2"))

for i in range(num_iter):
    title2.append(tlist2[i].get_text())
    artist2.append(alist2[i].get_text())

# %%
more_songs = pd.DataFrame({'song':title2, 'artist':artist2})
more_songs
# Out:
#                                     song                           artist
# 0                      Fight The Power\n                   Public Enemy\n
# 1                        Like a Prayer\n                        Madonna\n
# 2                         Free Fallin'\n                      Tom Petty\n
# 3                     The Humpty Dance\n            Digital Underground\n
# 4                      Pump Up The Jam\n     Technotronic (feat. Felly)\n
# ..                                   ...                              ...
# 95                             Falling\n                   Julee Cruise\n
# 96                  I Get the Job Done\n                 Big Daddy Kane\n
# 97                When I See You Smile\n                    Bad English\n
# 98                             Forever\n                           KISS\n
# 99  Get Up! (Before the Night Is Over)\n  Technotronic (feat. Ya Kid K)\n
#
# [100 rows x 2 columns]

# %% [markdown]
# Cleaning the \n from my Dataframe

# %%
song_lst = []
for i in more_songs['song']:
    if '\n' in i:
        i = i.split('\n')[0]
        song_lst.append(i)
        
more_songs['song'] = song_lst        
more_songs['song']
# Out:
# 0                        Fight The Power
# 1                          Like a Prayer
# 2                           Free Fallin'
# 3                       The Humpty Dance
# 4                        Pump Up The Jam
#                      ...
# 95                               Falling
# 96                    I Get the Job Done
# 97                  When I See You Smile
# 98                               Forever
# 99    Get Up! (Before the Night Is Over)
# Name: song, Length: 100, dtype: object

# %%
art_lst = []
for i in more_songs['artist']:
    if '\n' in i:
        i = i.split('\n')[0]
        art_lst.append(i)
        
more_songs['artist'] = art_lst        
more_songs['artist']
# Out:
# 0                      Public Enemy
# 1                           Madonna
# 2                         Tom Petty
# 3               Digital Underground
# 4        Technotronic (feat. Felly)
#                   ...
# 95                     Julee Cruise
# 96                   Big Daddy Kane
# 97                      Bad English
# 98                             KISS
# 99    Technotronic (feat. Ya Kid K)
# Name: artist, Length: 100, dtype: object

# %%
more_songs
# Out:
#                                   song                         artist
# 0                      Fight The Power                   Public Enemy
# 1                        Like a Prayer                        Madonna
# 2                         Free Fallin'                      Tom Petty
# 3                     The Humpty Dance            Digital Underground
# 4                      Pump Up The Jam     Technotronic (feat. Felly)
# ..                                 ...                            ...
# 95                             Falling                   Julee Cruise
# 96                  I Get the Job Done                 Big Daddy Kane
# 97                When I See You Smile                    Bad English
# 98                             Forever                           KISS
# 99  Get Up! (Before the Night Is Over)  Technotronic (feat. Ya Kid K)
#
# [100 rows x 2 columns]

# %% [markdown]
# Concat both Dataframes

# %%
song_df = pd.concat([song_df, more_songs], axis=0).reset_index()

# %%
song_df
# Out:
#      index                                song                         artist
# 0        0                              Unholy         Sam Smith & Kim Petras
# 1        1                     I'm Good (Blue)      David Guetta & Bebe Rexha
# 2        2                           Thank God     Kane Brown & Katelyn Brown
# 3        3                       Face It Alone                          Queen
# 4        4                   wait in the truck          HARDY & Lainey Wilson
# ..     ...                                 ...                            ...
# 195     95                             Falling                   Julee Cruise
# 196     96                  I Get the Job Done                 Big Daddy Kane
# 197     97                When I See You Smile                    Bad English
# 198     98                             Forever                           KISS
# 199     99  Get Up! (Before the Night Is Over)  Technotronic (feat. Ya Kid K)
#
# [200 rows x 3 columns]

# %%
song_df = song_df.drop(['index'], axis=1)
song_df
# Out:
#                                    song                         artist
# 0                                Unholy         Sam Smith & Kim Petras
# 1                       I'm Good (Blue)      David Guetta & Bebe Rexha
# 2                             Thank God     Kane Brown & Katelyn Brown
# 3                         Face It Alone                          Queen
# 4                     wait in the truck          HARDY & Lainey Wilson
# ..                                  ...                            ...
# 195                             Falling                   Julee Cruise
# 196                  I Get the Job Done                 Big Daddy Kane
# 197                When I See You Smile                    Bad English
# 198                             Forever                           KISS
# 199  Get Up! (Before the Night Is Over)  Technotronic (feat. Ya Kid K)
#
# [200 rows x 2 columns]

# %% [markdown]
# # Song Recommender

# %%
import random

# %%
def recommender(df):    
    random_song = random.choice(df['song'])
    user_input = input("What is your favourite song?: ")
    if user_input.lower() == random_song.lower():
        random_song = random.choice(df['song']) 
    if user_input.lower() in df['song'].str.lower().values:
        print("We recommend the following song: ", random_song)
        again = input("Do you want to enter another song? y/n ")
        if again.lower() == 'y':
            recommender()
        else:
            print('Thank you for using our song recommender!')    
    else:
        print("We are sorry but we have no songs to recommend")
        again = input("Do you want to enter another song? y/n ")
        if again.lower() == 'y':
            recommender()
        else:
            print('Thank you for using our song recommender!')

# %%
recommender(song_df)
# Out:
# What is your favourite song?: b
# We are sorry but we have no songs to recommend
# Do you want to enter another song? y/n n
# Thank you for using our song recommender!

# %% [markdown]
# # Collection Playlists from Spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from random import randint
from time import sleep

# %% [markdown]
# Making connection

# %%
secrets_file = open(r"C:\Users\jasmi\Ironhack\secrets.txt","r")
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# getting the playlists

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000)
    return tracks

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"],track["uri"]) for artist in track["artists"]]

# %%
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
def get_name_artists_from_playlist(input_playlist):
    return flatten(list(map(get_name_artist_from_playlist_item,input_playlist["items"])))

# %% [markdown]
# ### 1st Playlist

# %%
# playlist1 = sp.user_playlist_tracks("spotify", "6Zf2l42EnOdAEwD2BlbmMl")

# %%
# playlist1 = get_name_artists_from_playlist(playlist1)

# %%
playlist1 = get_playlist_tracks("6Zf2l42EnOdAEwD2BlbmMl")

# %%
playlst_1 = list(map(get_name_artist_from_playlist_item,playlist1))

# %%
playlst1 = flatten(playlst_1)

# %%
# playlst1

# %%
df_1 = pd.DataFrame(playlst1)
df_1
# Out:
#                                     0                 1  \
# 0                (You Drive Me) Crazy    Britney Spears
# 1                         Barbie Girl              Aqua
# 2                         Coco Jamboo     Mr. President
# 3                        Irresistible   Jessica Simpson
# 4            Uptown Girl - Radio Edit          Westlife
# ..                                ...               ...
# 62                               Baby     Justin Bieber
# 63                               Baby          Ludacris
# 64                        Battlefield     Jordin Sparks
# 65  Stereo Hearts (feat. Adam Levine)  Gym Class Heroes
# 66  Stereo Hearts (feat. Adam Levine)       Adam Levine
#
#                                        2
# 0   spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 1   spotify:track:5ZrDlcxIDZyjOzHdYW1ydr
# 2   spotify:track:5fRvePkRGdpn2nKacG7I6d
# 3   spotify:track:20NKCc2ag4FT1DLk0C2oT5
# 4   spotify:track:2sFp6E7lNBbblJGmUtCfFH
# ..                                   ...
# 62  spotify:track:6epn3r7S14KUqlReYr77hA
# 63  spotify:track:6epn3r7S14KUqlReYr77hA
# 64  spotify:track:4hJNA7VCBfNDly2Lz1SKAt
# 65  spotify:track:0qOnSQQF0yzuPWsXrQ9paz
# 66  spotify:track:0qOnSQQF0yzuPWsXrQ9paz
#
# [67 rows x 3 columns]

# %%
audio1 = []

for x in df_1[2]:
    audio1.append(sp.audio_features(x))

# %%
audio1 = flatten(audio1)

# %%
audio1_df = pd.DataFrame(audio1)

# %%
audio1_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.748   0.939    0    -4.288     0       0.0341       0.05340
# 1          0.812   0.879    1   -10.998     0       0.0397       0.01670
# 2          0.832   0.838    1    -5.414     0       0.0421       0.07910
# 3          0.657   0.965    8    -2.771     0       0.0556       0.02850
# 4          0.645   0.921    6    -5.256     0       0.0302       0.00809
# ..           ...     ...  ...       ...   ...          ...           ...
# 62         0.728   0.859    5    -5.237     0       0.1370       0.04010
# 63         0.728   0.859    5    -5.237     0       0.1370       0.04010
# 64         0.613   0.634    2    -3.472     1       0.0339       0.01780
# 65         0.646   0.795    9    -3.293     1       0.0976       0.03190
# 66         0.646   0.795    9    -3.293     1       0.0976       0.03190
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.3200    0.960  104.001  audio_features
# 1           0.224000    0.3660    0.962  129.991  audio_features
# 2           0.000000    0.1520    0.965  100.021  audio_features
# 3           0.000088    0.0552    0.669   93.013  audio_features
# 4           0.000011    0.4070    0.864  129.000  audio_features
# ..               ...       ...      ...      ...             ...
# 62          0.000000    0.1110    0.535   65.043  audio_features
# 63          0.000000    0.1110    0.535   65.043  audio_features
# 64          0.000000    0.0639    0.370  144.953  audio_features
# 65          0.000000    0.2670    0.796   89.990  audio_features
# 66          0.000000    0.2670    0.796   89.990  audio_features
#
#                         id                                   uri  \
# 0   1DSJNBNhGZCigg9ll5VeZv  spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 1   5ZrDlcxIDZyjOzHdYW1ydr  spotify:track:5ZrDlcxIDZyjOzHdYW1ydr
# 2   5fRvePkRGdpn2nKacG7I6d  spotify:track:5fRvePkRGdpn2nKacG7I6d
# 3   20NKCc2ag4FT1DLk0C2oT5  spotify:track:20NKCc2ag4FT1DLk0C2oT5
# 4   2sFp6E7lNBbblJGmUtCfFH  spotify:track:2sFp6E7lNBbblJGmUtCfFH
# ..                     ...                                   ...
# 62  6epn3r7S14KUqlReYr77hA  spotify:track:6epn3r7S14KUqlReYr77hA
# 63  6epn3r7S14KUqlReYr77hA  spotify:track:6epn3r7S14KUqlReYr77hA
# 64  4hJNA7VCBfNDly2Lz1SKAt  spotify:track:4hJNA7VCBfNDly2Lz1SKAt
# 65  0qOnSQQF0yzuPWsXrQ9paz  spotify:track:0qOnSQQF0yzuPWsXrQ9paz
# 66  0qOnSQQF0yzuPWsXrQ9paz  spotify:track:0qOnSQQF0yzuPWsXrQ9paz
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/1DSJNBNhGZCi...
# 1   https://api.spotify.com/v1/tracks/5ZrDlcxIDZyj...
# 2   https://api.spotify.com/v1/tracks/5fRvePkRGdpn...
# 3   https://api.spotify.com/v1/tracks/20NKCc2ag4FT...
# 4   https://api.spotify.com/v1/tracks/2sFp6E7lNBbb...
# ..                                                ...
# 62  https://api.spotify.com/v1/tracks/6epn3r7S14KU...
# 63  https://api.spotify.com/v1/tracks/6epn3r7S14KU...
# 64  https://api.spotify.com/v1/tracks/4hJNA7VCBfND...
# 65  https://api.spotify.com/v1/tracks/0qOnSQQF0yzu...
# 66  https://api.spotify.com/v1/tracks/0qOnSQQF0yzu...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/1DSJ...       198067
# 1   https://api.spotify.com/v1/audio-analysis/5ZrD...       197960
# 2   https://api.spotify.com/v1/audio-analysis/5fRv...       218733
# 3   https://api.spotify.com/v1/audio-analysis/20NK...       194027
# 4   https://api.spotify.com/v1/audio-analysis/2sFp...       186440
# ..                                                ...          ...
# 62  https://api.spotify.com/v1/audio-analysis/6epn...       214240
# 63  https://api.spotify.com/v1/audio-analysis/6epn...       214240
# 64  https://api.spotify.com/v1/audio-analysis/4hJN...       241920
# 65  https://api.spotify.com/v1/audio-analysis/0qOn...       210960
# 66  https://api.spotify.com/v1/audio-analysis/0qOn...       210960
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 62               4
# 63               4
# 64               4
# 65               4
# 66               4
#
# [67 rows x 18 columns]

# %%
play_1 = pd.concat([df_1 , audio1_df], axis=1)

# %%
play_1
# Out:
#                                     0                 1  \
# 0                (You Drive Me) Crazy    Britney Spears
# 1                         Barbie Girl              Aqua
# 2                         Coco Jamboo     Mr. President
# 3                        Irresistible   Jessica Simpson
# 4            Uptown Girl - Radio Edit          Westlife
# ..                                ...               ...
# 62                               Baby     Justin Bieber
# 63                               Baby          Ludacris
# 64                        Battlefield     Jordin Sparks
# 65  Stereo Hearts (feat. Adam Levine)  Gym Class Heroes
# 66  Stereo Hearts (feat. Adam Levine)       Adam Levine
#
#                                        2  danceability  energy  key  loudness  \
# 0   spotify:track:1DSJNBNhGZCigg9ll5VeZv         0.748   0.939    0    -4.288
# 1   spotify:track:5ZrDlcxIDZyjOzHdYW1ydr         0.812   0.879    1   -10.998
# 2   spotify:track:5fRvePkRGdpn2nKacG7I6d         0.832   0.838    1    -5.414
# 3   spotify:track:20NKCc2ag4FT1DLk0C2oT5         0.657   0.965    8    -2.771
# 4   spotify:track:2sFp6E7lNBbblJGmUtCfFH         0.645   0.921    6    -5.256
# ..                                   ...           ...     ...  ...       ...
# 62  spotify:track:6epn3r7S14KUqlReYr77hA         0.728   0.859    5    -5.237
# 63  spotify:track:6epn3r7S14KUqlReYr77hA         0.728   0.859    5    -5.237
# 64  spotify:track:4hJNA7VCBfNDly2Lz1SKAt         0.613   0.634    2    -3.472
# 65  spotify:track:0qOnSQQF0yzuPWsXrQ9paz         0.646   0.795    9    -3.293
# 66  spotify:track:0qOnSQQF0yzuPWsXrQ9paz         0.646   0.795    9    -3.293
#
#     mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0      0       0.0341       0.05340  ...    0.3200    0.960  104.001
# 1      0       0.0397       0.01670  ...    0.3660    0.962  129.991
# 2      0       0.0421       0.07910  ...    0.1520    0.965  100.021
# 3      0       0.0556       0.02850  ...    0.0552    0.669   93.013
# 4      0       0.0302       0.00809  ...    0.4070    0.864  129.000
# ..   ...          ...           ...  ...       ...      ...      ...
# 62     0       0.1370       0.04010  ...    0.1110    0.535   65.043
# 63     0       0.1370       0.04010  ...    0.1110    0.535   65.043
# 64     1       0.0339       0.01780  ...    0.0639    0.370  144.953
# 65     1       0.0976       0.03190  ...    0.2670    0.796   89.990
# 66     1       0.0976       0.03190  ...    0.2670    0.796   89.990
#
#               type                      id  \
# 0   audio_features  1DSJNBNhGZCigg9ll5VeZv
# 1   audio_features  5ZrDlcxIDZyjOzHdYW1ydr
# 2   audio_features  5fRvePkRGdpn2nKacG7I6d
# 3   audio_features  20NKCc2ag4FT1DLk0C2oT5
# 4   audio_features  2sFp6E7lNBbblJGmUtCfFH
# ..             ...                     ...
# 62  audio_features  6epn3r7S14KUqlReYr77hA
# 63  audio_features  6epn3r7S14KUqlReYr77hA
# 64  audio_features  4hJNA7VCBfNDly2Lz1SKAt
# 65  audio_features  0qOnSQQF0yzuPWsXrQ9paz
# 66  audio_features  0qOnSQQF0yzuPWsXrQ9paz
#
#                                      uri  \
# 0   spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 1   spotify:track:5ZrDlcxIDZyjOzHdYW1ydr
# 2   spotify:track:5fRvePkRGdpn2nKacG7I6d
# 3   spotify:track:20NKCc2ag4FT1DLk0C2oT5
# 4   spotify:track:2sFp6E7lNBbblJGmUtCfFH
# ..                                   ...
# 62  spotify:track:6epn3r7S14KUqlReYr77hA
# 63  spotify:track:6epn3r7S14KUqlReYr77hA
# 64  spotify:track:4hJNA7VCBfNDly2Lz1SKAt
# 65  spotify:track:0qOnSQQF0yzuPWsXrQ9paz
# 66  spotify:track:0qOnSQQF0yzuPWsXrQ9paz
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/1DSJNBNhGZCi...
# 1   https://api.spotify.com/v1/tracks/5ZrDlcxIDZyj...
# 2   https://api.spotify.com/v1/tracks/5fRvePkRGdpn...
# 3   https://api.spotify.com/v1/tracks/20NKCc2ag4FT...
# 4   https://api.spotify.com/v1/tracks/2sFp6E7lNBbb...
# ..                                                ...
# 62  https://api.spotify.com/v1/tracks/6epn3r7S14KU...
# 63  https://api.spotify.com/v1/tracks/6epn3r7S14KU...
# 64  https://api.spotify.com/v1/tracks/4hJNA7VCBfND...
# 65  https://api.spotify.com/v1/tracks/0qOnSQQF0yzu...
# 66  https://api.spotify.com/v1/tracks/0qOnSQQF0yzu...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/1DSJ...      198067
# 1   https://api.spotify.com/v1/audio-analysis/5ZrD...      197960
# 2   https://api.spotify.com/v1/audio-analysis/5fRv...      218733
# 3   https://api.spotify.com/v1/audio-analysis/20NK...      194027
# 4   https://api.spotify.com/v1/audio-analysis/2sFp...      186440
# ..                                                ...         ...
# 62  https://api.spotify.com/v1/audio-analysis/6epn...      214240
# 63  https://api.spotify.com/v1/audio-analysis/6epn...      214240
# 64  https://api.spotify.com/v1/audio-analysis/4hJN...      241920
# 65  https://api.spotify.com/v1/audio-analysis/0qOn...      210960
# 66  https://api.spotify.com/v1/audio-analysis/0qOn...      210960
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 62               4
# 63               4
# 64               4
# 65               4
# 66               4
#
# [67 rows x 21 columns]

# %% [markdown]
# ### 2nd Playlist

# %%
playlist2 = get_playlist_tracks("2QJV8b3OPIUoFQBOb2IK5U")

# %%
get_name_artist_from_playlist_item(playlist2[0])
# Out:
# [('Fuego', 'Eleni Foureira', 'spotify:track:4TwWOcvjY1qt3QJvtveAGm')]

# %%
playlst_2 = list(map(get_name_artist_from_playlist_item,playlist2))

# %%
len(playlst_2)
# Out:
# 371

# %%
playlst_2= flatten(playlst_2)

# %%
# playlst_2

# %%
df_2 = pd.DataFrame(playlst_2)
df_2
# Out:
#                                                      0               1  \
# 0                                                Fuego  Eleni Foureira
# 1                                                  Toy           Netta
# 2                                             Monsters     Saara Aalto
# 3                                            Lie to Me   Mikolas Josef
# 4    Je Ne Sais Quoi (Eurovision 2010) Orginal Version      Hera Björk
# ..                                                 ...             ...
# 387                                             SEKRET   Ronela Hajati
# 388                                          SPACE MAN       Sam Ryder
# 389                                          De Diepte             S10
# 390                                               SNAP       Rosa Linn
# 391                                         Horehronie        Kristína
#
#                                         2
# 0    spotify:track:4TwWOcvjY1qt3QJvtveAGm
# 1    spotify:track:6n2eIfLj0wOOUkUfNmYzlh
# 2    spotify:track:0JGbU6NlewrskD138Wq04b
# 3    spotify:track:4Ot9gTaARnRqJT1TYwM4pQ
# 4    spotify:track:48rIGviK0uiZKmXV6QifbE
# ..                                    ...
# 387  spotify:track:0zC65JcBBk4GYAjL2tHKXa
# 388  spotify:track:3nhGk6VnrDHy67pXvMhdPa
# 389  spotify:track:7uQ7e7nzbtyX87eIYHpj6Z
# 390  spotify:track:0QPRDC97rIQB3Jh3hrVJoH
# 391  spotify:track:2SSBF42WitdTTkAJGv9Ugm
#
# [392 rows x 3 columns]

# %%
audio2 = []

for x in df_2[2]:
    audio2.append(sp.audio_features(x))

# %%
audio2 = flatten(audio2)
audio2_df = pd.DataFrame(audio2)
audio2_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.586   0.739   11    -4.584     0       0.1050       0.05580
# 1           0.786   0.712    3    -5.349     0       0.0678       0.07060
# 2           0.581   0.731    0    -4.482     0       0.0387       0.01030
# 3           0.836   0.688    6    -6.528     1       0.1210       0.00442
# 4           0.529   0.878    3    -4.328     0       0.0668       0.03430
# ..            ...     ...  ...       ...   ...          ...           ...
# 387         0.760   0.695    5    -6.088     0       0.0502       0.04510
# 388         0.467   0.828   11    -2.220     1       0.0489       0.18100
# 389         0.502   0.397    2    -8.819     0       0.0282       0.37800
# 390         0.563   0.639    0    -8.205     1       0.0684       0.10700
# 391         0.708   0.907    1    -4.757     1       0.0690       0.13000
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.5790    0.522  101.033  audio_features
# 1            0.000000    0.2360    0.795  130.144  audio_features
# 2            0.000000    0.0602    0.272  121.931  audio_features
# 3            0.000002    0.3910    0.699  106.013  audio_features
# 4            0.000003    0.1720    0.285  132.033  audio_features
# ..                ...       ...      ...      ...             ...
# 387          0.004130    0.5150    0.452  100.005  audio_features
# 388          0.000000    0.1020    0.334   79.978  audio_features
# 389          0.000034    0.1430    0.159   90.043  audio_features
# 390          0.000011    0.4460    0.518  169.985  audio_features
# 391          0.000002    0.2870    0.482  119.981  audio_features
#
#                          id                                   uri  \
# 0    4TwWOcvjY1qt3QJvtveAGm  spotify:track:4TwWOcvjY1qt3QJvtveAGm
# 1    6n2eIfLj0wOOUkUfNmYzlh  spotify:track:6n2eIfLj0wOOUkUfNmYzlh
# 2    0JGbU6NlewrskD138Wq04b  spotify:track:0JGbU6NlewrskD138Wq04b
# 3    4Ot9gTaARnRqJT1TYwM4pQ  spotify:track:4Ot9gTaARnRqJT1TYwM4pQ
# 4    48rIGviK0uiZKmXV6QifbE  spotify:track:48rIGviK0uiZKmXV6QifbE
# ..                      ...                                   ...
# 387  0zC65JcBBk4GYAjL2tHKXa  spotify:track:0zC65JcBBk4GYAjL2tHKXa
# 388  3nhGk6VnrDHy67pXvMhdPa  spotify:track:3nhGk6VnrDHy67pXvMhdPa
# 389  7uQ7e7nzbtyX87eIYHpj6Z  spotify:track:7uQ7e7nzbtyX87eIYHpj6Z
# 390  0QPRDC97rIQB3Jh3hrVJoH  spotify:track:0QPRDC97rIQB3Jh3hrVJoH
# 391  2SSBF42WitdTTkAJGv9Ugm  spotify:track:2SSBF42WitdTTkAJGv9Ugm
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4TwWOcvjY1qt...
# 1    https://api.spotify.com/v1/tracks/6n2eIfLj0wOO...
# 2    https://api.spotify.com/v1/tracks/0JGbU6Nlewrs...
# 3    https://api.spotify.com/v1/tracks/4Ot9gTaARnRq...
# 4    https://api.spotify.com/v1/tracks/48rIGviK0uiZ...
# ..                                                 ...
# 387  https://api.spotify.com/v1/tracks/0zC65JcBBk4G...
# 388  https://api.spotify.com/v1/tracks/3nhGk6VnrDHy...
# 389  https://api.spotify.com/v1/tracks/7uQ7e7nzbtyX...
# 390  https://api.spotify.com/v1/tracks/0QPRDC97rIQB...
# 391  https://api.spotify.com/v1/tracks/2SSBF42WitdT...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4TwW...       183397
# 1    https://api.spotify.com/v1/audio-analysis/6n2e...       180231
# 2    https://api.spotify.com/v1/audio-analysis/0JGb...       180587
# 3    https://api.spotify.com/v1/audio-analysis/4Ot9...       170000
# 4    https://api.spotify.com/v1/audio-analysis/48rI...       180001
# ..                                                 ...          ...
# 387  https://api.spotify.com/v1/audio-analysis/0zC6...       181117
# 388  https://api.spotify.com/v1/audio-analysis/3nhG...       217320
# 389  https://api.spotify.com/v1/audio-analysis/7uQ7...       176604
# 390  https://api.spotify.com/v1/audio-analysis/0QPR...       179551
# 391  https://api.spotify.com/v1/audio-analysis/2SSB...       183133
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 387               4
# 388               4
# 389               4
# 390               4
# 391               4
#
# [392 rows x 18 columns]

# %%
play_2 = pd.concat([df_2 , audio2_df], axis=1)

# %%
play_2
# Out:
#                                                      0               1  \
# 0                                                Fuego  Eleni Foureira
# 1                                                  Toy           Netta
# 2                                             Monsters     Saara Aalto
# 3                                            Lie to Me   Mikolas Josef
# 4    Je Ne Sais Quoi (Eurovision 2010) Orginal Version      Hera Björk
# ..                                                 ...             ...
# 387                                             SEKRET   Ronela Hajati
# 388                                          SPACE MAN       Sam Ryder
# 389                                          De Diepte             S10
# 390                                               SNAP       Rosa Linn
# 391                                         Horehronie        Kristína
#
#                                         2  danceability  energy  key  \
# 0    spotify:track:4TwWOcvjY1qt3QJvtveAGm         0.586   0.739   11
# 1    spotify:track:6n2eIfLj0wOOUkUfNmYzlh         0.786   0.712    3
# 2    spotify:track:0JGbU6NlewrskD138Wq04b         0.581   0.731    0
# 3    spotify:track:4Ot9gTaARnRqJT1TYwM4pQ         0.836   0.688    6
# 4    spotify:track:48rIGviK0uiZKmXV6QifbE         0.529   0.878    3
# ..                                    ...           ...     ...  ...
# 387  spotify:track:0zC65JcBBk4GYAjL2tHKXa         0.760   0.695    5
# 388  spotify:track:3nhGk6VnrDHy67pXvMhdPa         0.467   0.828   11
# 389  spotify:track:7uQ7e7nzbtyX87eIYHpj6Z         0.502   0.397    2
# 390  spotify:track:0QPRDC97rIQB3Jh3hrVJoH         0.563   0.639    0
# 391  spotify:track:2SSBF42WitdTTkAJGv9Ugm         0.708   0.907    1
#
#      loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0      -4.584     0       0.1050       0.05580  ...    0.5790    0.522
# 1      -5.349     0       0.0678       0.07060  ...    0.2360    0.795
# 2      -4.482     0       0.0387       0.01030  ...    0.0602    0.272
# 3      -6.528     1       0.1210       0.00442  ...    0.3910    0.699
# 4      -4.328     0       0.0668       0.03430  ...    0.1720    0.285
# ..        ...   ...          ...           ...  ...       ...      ...
# 387    -6.088     0       0.0502       0.04510  ...    0.5150    0.452
# 388    -2.220     1       0.0489       0.18100  ...    0.1020    0.334
# 389    -8.819     0       0.0282       0.37800  ...    0.1430    0.159
# 390    -8.205     1       0.0684       0.10700  ...    0.4460    0.518
# 391    -4.757     1       0.0690       0.13000  ...    0.2870    0.482
#
#        tempo            type                      id  \
# 0    101.033  audio_features  4TwWOcvjY1qt3QJvtveAGm
# 1    130.144  audio_features  6n2eIfLj0wOOUkUfNmYzlh
# 2    121.931  audio_features  0JGbU6NlewrskD138Wq04b
# 3    106.013  audio_features  4Ot9gTaARnRqJT1TYwM4pQ
# 4    132.033  audio_features  48rIGviK0uiZKmXV6QifbE
# ..       ...             ...                     ...
# 387  100.005  audio_features  0zC65JcBBk4GYAjL2tHKXa
# 388   79.978  audio_features  3nhGk6VnrDHy67pXvMhdPa
# 389   90.043  audio_features  7uQ7e7nzbtyX87eIYHpj6Z
# 390  169.985  audio_features  0QPRDC97rIQB3Jh3hrVJoH
# 391  119.981  audio_features  2SSBF42WitdTTkAJGv9Ugm
#
#                                       uri  \
# 0    spotify:track:4TwWOcvjY1qt3QJvtveAGm
# 1    spotify:track:6n2eIfLj0wOOUkUfNmYzlh
# 2    spotify:track:0JGbU6NlewrskD138Wq04b
# 3    spotify:track:4Ot9gTaARnRqJT1TYwM4pQ
# 4    spotify:track:48rIGviK0uiZKmXV6QifbE
# ..                                    ...
# 387  spotify:track:0zC65JcBBk4GYAjL2tHKXa
# 388  spotify:track:3nhGk6VnrDHy67pXvMhdPa
# 389  spotify:track:7uQ7e7nzbtyX87eIYHpj6Z
# 390  spotify:track:0QPRDC97rIQB3Jh3hrVJoH
# 391  spotify:track:2SSBF42WitdTTkAJGv9Ugm
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4TwWOcvjY1qt...
# 1    https://api.spotify.com/v1/tracks/6n2eIfLj0wOO...
# 2    https://api.spotify.com/v1/tracks/0JGbU6Nlewrs...
# 3    https://api.spotify.com/v1/tracks/4Ot9gTaARnRq...
# 4    https://api.spotify.com/v1/tracks/48rIGviK0uiZ...
# ..                                                 ...
# 387  https://api.spotify.com/v1/tracks/0zC65JcBBk4G...
# 388  https://api.spotify.com/v1/tracks/3nhGk6VnrDHy...
# 389  https://api.spotify.com/v1/tracks/7uQ7e7nzbtyX...
# 390  https://api.spotify.com/v1/tracks/0QPRDC97rIQB...
# 391  https://api.spotify.com/v1/tracks/2SSBF42WitdT...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4TwW...      183397
# 1    https://api.spotify.com/v1/audio-analysis/6n2e...      180231
# 2    https://api.spotify.com/v1/audio-analysis/0JGb...      180587
# 3    https://api.spotify.com/v1/audio-analysis/4Ot9...      170000
# 4    https://api.spotify.com/v1/audio-analysis/48rI...      180001
# ..                                                 ...         ...
# 387  https://api.spotify.com/v1/audio-analysis/0zC6...      181117
# 388  https://api.spotify.com/v1/audio-analysis/3nhG...      217320
# 389  https://api.spotify.com/v1/audio-analysis/7uQ7...      176604
# 390  https://api.spotify.com/v1/audio-analysis/0QPR...      179551
# 391  https://api.spotify.com/v1/audio-analysis/2SSB...      183133
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 387               4
# 388               4
# 389               4
# 390               4
# 391               4
#
# [392 rows x 21 columns]

# %% [markdown]
# ### 3rd Playlist

# %%
playlist3 = get_playlist_tracks('0gqrnk12Q8OExuCeKyBRCq')

# %%
playlst_3 = list(map(get_name_artist_from_playlist_item,playlist3))

# %%
playlst_3 = flatten(playlst_3)

# %%
len(playlst_3)
# Out:
# 514

# %%
# playlst_3

# %%
df_3 = pd.DataFrame(playlst_3)
df_3
# Out:
#                                               0                      1  \
# 0                                     September     Earth, Wind & Fire
# 1                                      All Star            Smash Mouth
# 2                            Where Is The Love?        Black Eyed Peas
# 3                               Californication  Red Hot Chili Peppers
# 4                               I Gotta Feeling        Black Eyed Peas
# ..                                          ...                    ...
# 509                            Need You Tonight                   INXS
# 510    Wavin' Flag - Coca-Cola® Celebration Mix                 K'NAAN
# 511                        Listen To Your Heart                Roxette
# 512  Burning Heart - From "Rocky IV" Soundtrack               Survivor
# 513                            Someone Like You                  Adele
#
#                                         2
# 0    spotify:track:5nNmj1cLH3r4aA4XDJ2bgY
# 1    spotify:track:22c2pt75xtnDddA5Zlm0yy
# 2    spotify:track:0uqPG793dkDDN7sCUJJIVC
# 3    spotify:track:48UPSzbZjgc449aqz8bxox
# 4    spotify:track:70cTMpcgWMcR18t9MRJFjB
# ..                                    ...
# 509  spotify:track:3h04eZTnmFLRMjZajbrp2R
# 510  spotify:track:6WFQsZZa81anp9BkqZMyTb
# 511  spotify:track:5JvsxPAHsGxwNq4xto2HtM
# 512  spotify:track:2VN7uPrbryJ7nE2MXX3f9a
# 513  spotify:track:3bNv3VuUOKgrf5hu3YcuRo
#
# [514 rows x 3 columns]

# %%
audio3 = []

for x in df_3[2]:
    audio3.append(sp.audio_features(x))

# %%
audio3 = flatten(audio3)
audio3_df = pd.DataFrame(audio3)
audio3_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.697   0.809    9    -8.197     1       0.0302        0.1140
# 1           0.730   0.862   11    -5.876     1       0.0313        0.0398
# 2           0.835   0.687    5    -3.180     1       0.1840        0.1010
# 3           0.592   0.767    9    -2.788     0       0.0270        0.0021
# 4           0.743   0.766    0    -6.375     1       0.0265        0.0873
# ..            ...     ...  ...       ...   ...          ...           ...
# 509         0.795   0.630   10    -7.217     0       0.0841        0.0419
# 510         0.583   0.791    0    -4.192     1       0.0644        0.3090
# 511         0.539   0.583    1    -4.935     0       0.0275        0.1080
# 512         0.652   0.609    9    -9.684     0       0.0280        0.2980
# 513         0.556   0.319    9    -8.251     1       0.0281        0.8930
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000521    0.1830    0.980  125.941  audio_features
# 1            0.000000    0.0818    0.770  104.018  audio_features
# 2            0.000000    0.1320    0.828   94.059  audio_features
# 3            0.001650    0.1270    0.328   96.483  audio_features
# 4            0.000000    0.5090    0.610  127.960  audio_features
# ..                ...       ...      ...      ...             ...
# 509          0.575000    0.0894    0.785  108.701  audio_features
# 510          0.000000    0.0996    0.615  151.869  audio_features
# 511          0.000000    0.1110    0.337   86.063  audio_features
# 512          0.000009    0.0573    0.646   98.125  audio_features
# 513          0.000000    0.0996    0.294  135.187  audio_features
#
#                          id                                   uri  \
# 0    5nNmj1cLH3r4aA4XDJ2bgY  spotify:track:5nNmj1cLH3r4aA4XDJ2bgY
# 1    22c2pt75xtnDddA5Zlm0yy  spotify:track:22c2pt75xtnDddA5Zlm0yy
# 2    0uqPG793dkDDN7sCUJJIVC  spotify:track:0uqPG793dkDDN7sCUJJIVC
# 3    48UPSzbZjgc449aqz8bxox  spotify:track:48UPSzbZjgc449aqz8bxox
# 4    70cTMpcgWMcR18t9MRJFjB  spotify:track:70cTMpcgWMcR18t9MRJFjB
# ..                      ...                                   ...
# 509  3h04eZTnmFLRMjZajbrp2R  spotify:track:3h04eZTnmFLRMjZajbrp2R
# 510  6WFQsZZa81anp9BkqZMyTb  spotify:track:6WFQsZZa81anp9BkqZMyTb
# 511  5JvsxPAHsGxwNq4xto2HtM  spotify:track:5JvsxPAHsGxwNq4xto2HtM
# 512  2VN7uPrbryJ7nE2MXX3f9a  spotify:track:2VN7uPrbryJ7nE2MXX3f9a
# 513  3bNv3VuUOKgrf5hu3YcuRo  spotify:track:3bNv3VuUOKgrf5hu3YcuRo
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5nNmj1cLH3r4...
# 1    https://api.spotify.com/v1/tracks/22c2pt75xtnD...
# 2    https://api.spotify.com/v1/tracks/0uqPG793dkDD...
# 3    https://api.spotify.com/v1/tracks/48UPSzbZjgc4...
# 4    https://api.spotify.com/v1/tracks/70cTMpcgWMcR...
# ..                                                 ...
# 509  https://api.spotify.com/v1/tracks/3h04eZTnmFLR...
# 510  https://api.spotify.com/v1/tracks/6WFQsZZa81an...
# 511  https://api.spotify.com/v1/tracks/5JvsxPAHsGxw...
# 512  https://api.spotify.com/v1/tracks/2VN7uPrbryJ7...
# 513  https://api.spotify.com/v1/tracks/3bNv3VuUOKgr...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5nNm...       214827
# 1    https://api.spotify.com/v1/audio-analysis/22c2...       200560
# 2    https://api.spotify.com/v1/audio-analysis/0uqP...       272533
# 3    https://api.spotify.com/v1/audio-analysis/48UP...       329733
# 4    https://api.spotify.com/v1/audio-analysis/70cT...       289133
# ..                                                 ...          ...
# 509  https://api.spotify.com/v1/audio-analysis/3h04...       181107
# 510  https://api.spotify.com/v1/audio-analysis/6WFQ...       212507
# 511  https://api.spotify.com/v1/audio-analysis/5Jvs...       328093
# 512  https://api.spotify.com/v1/audio-analysis/2VN7...       230107
# 513  https://api.spotify.com/v1/audio-analysis/3bNv...       285240
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 509               4
# 510               4
# 511               4
# 512               4
# 513               4
#
# [514 rows x 18 columns]

# %%
play_3 = pd.concat([df_3 , audio3_df], axis=1)

# %% [markdown]
# ### 4th Playlist

# %%
playlist4 = get_playlist_tracks('77CxoauZX3xv8VsfVwPJxT')

# %%
playlst_4 = list(map(get_name_artist_from_playlist_item,playlist4))

# %%
playlst_4 = flatten(playlst_4)

# %%
len(playlst_4)
# Out:
# 2528

# %%
df_4 = pd.DataFrame(playlst_4)
df_4
# Out:
#                                            0                  1  \
# 0                            Like I Love You   Lost Frequencies
# 1                            Like I Love You         The NGHBRS
# 2                      Lost In Japan - Remix       Shawn Mendes
# 3                      Lost In Japan - Remix               Zedd
# 4                                      IDGAF           Dua Lipa
# ...                                      ...                ...
# 2523                             Okee Shordy              Chivv
# 2524                             Okee Shordy         ADF Samski
# 2525  EVERYTIME WE TOUCH HARDSTYLE (SPED UP)          SICK CVNT
# 2526  EVERYTIME WE TOUCH HARDSTYLE (SPED UP)  SPED UP SICK CVNT
# 2527  EVERYTIME WE TOUCH HARDSTYLE (SPED UP)     HARDSTYLE BRAH
#
#                                          2
# 0     spotify:track:4sh506lJZac1T4o4NqtIuS
# 1     spotify:track:4sh506lJZac1T4o4NqtIuS
# 2     spotify:track:575NJxNUVDqwJGdzBrlLbv
# 3     spotify:track:575NJxNUVDqwJGdzBrlLbv
# 4     spotify:track:76cy1WJvNGJTj78UqeA5zr
# ...                                    ...
# 2523  spotify:track:4RCKxit6c2kl7dwJPKT3hc
# 2524  spotify:track:4RCKxit6c2kl7dwJPKT3hc
# 2525  spotify:track:2dSNs47vHBSPnsUwpl39nk
# 2526  spotify:track:2dSNs47vHBSPnsUwpl39nk
# 2527  spotify:track:2dSNs47vHBSPnsUwpl39nk
#
# [2528 rows x 3 columns]

# %%
audio4 = []

for x in df_4[2]:
    audio4.append(sp.audio_features(x))

# %%
audio4 = flatten(audio4)
audio4_df = pd.DataFrame(audio4)
audio4_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.863   0.588    1    -7.141     1       0.0847        0.1420
# 1            0.863   0.588    1    -7.141     1       0.0847        0.1420
# 2            0.706   0.855   10    -5.377     1       0.2150        0.0911
# 3            0.706   0.855   10    -5.377     1       0.2150        0.0911
# 4            0.836   0.544    7    -5.975     1       0.0943        0.0403
# ...            ...     ...  ...       ...   ...          ...           ...
# 2523         0.855   0.698    8    -5.818     1       0.1220        0.2380
# 2524         0.855   0.698    8    -5.818     1       0.1220        0.2380
# 2525         0.554   0.874    1    -5.199     1       0.0480        0.2350
# 2526         0.554   0.874    1    -5.199     1       0.0480        0.2350
# 2527         0.554   0.874    1    -5.199     1       0.0480        0.2350
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000034    0.4570    0.751  117.911  audio_features
# 1             0.000034    0.4570    0.751  117.911  audio_features
# 2             0.000000    0.3470    0.293  107.184  audio_features
# 3             0.000000    0.3470    0.293  107.184  audio_features
# 4             0.000000    0.0824    0.510   97.028  audio_features
# ...                ...       ...      ...      ...             ...
# 2523          0.000000    0.0843    0.723  126.087  audio_features
# 2524          0.000000    0.0843    0.723  126.087  audio_features
# 2525          0.000000    0.3180    0.617  102.167  audio_features
# 2526          0.000000    0.3180    0.617  102.167  audio_features
# 2527          0.000000    0.3180    0.617  102.167  audio_features
#
#                           id                                   uri  \
# 0     4sh506lJZac1T4o4NqtIuS  spotify:track:4sh506lJZac1T4o4NqtIuS
# 1     4sh506lJZac1T4o4NqtIuS  spotify:track:4sh506lJZac1T4o4NqtIuS
# 2     575NJxNUVDqwJGdzBrlLbv  spotify:track:575NJxNUVDqwJGdzBrlLbv
# 3     575NJxNUVDqwJGdzBrlLbv  spotify:track:575NJxNUVDqwJGdzBrlLbv
# 4     76cy1WJvNGJTj78UqeA5zr  spotify:track:76cy1WJvNGJTj78UqeA5zr
# ...                      ...                                   ...
# 2523  4RCKxit6c2kl7dwJPKT3hc  spotify:track:4RCKxit6c2kl7dwJPKT3hc
# 2524  4RCKxit6c2kl7dwJPKT3hc  spotify:track:4RCKxit6c2kl7dwJPKT3hc
# 2525  2dSNs47vHBSPnsUwpl39nk  spotify:track:2dSNs47vHBSPnsUwpl39nk
# 2526  2dSNs47vHBSPnsUwpl39nk  spotify:track:2dSNs47vHBSPnsUwpl39nk
# 2527  2dSNs47vHBSPnsUwpl39nk  spotify:track:2dSNs47vHBSPnsUwpl39nk
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4sh506lJZac1...
# 1     https://api.spotify.com/v1/tracks/4sh506lJZac1...
# 2     https://api.spotify.com/v1/tracks/575NJxNUVDqw...
# 3     https://api.spotify.com/v1/tracks/575NJxNUVDqw...
# 4     https://api.spotify.com/v1/tracks/76cy1WJvNGJT...
# ...                                                 ...
# 2523  https://api.spotify.com/v1/tracks/4RCKxit6c2kl...
# 2524  https://api.spotify.com/v1/tracks/4RCKxit6c2kl...
# 2525  https://api.spotify.com/v1/tracks/2dSNs47vHBSP...
# 2526  https://api.spotify.com/v1/tracks/2dSNs47vHBSP...
# 2527  https://api.spotify.com/v1/tracks/2dSNs47vHBSP...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4sh5...       190174
# 1     https://api.spotify.com/v1/audio-analysis/4sh5...       190174
# 2     https://api.spotify.com/v1/audio-analysis/575N...       201253
# 3     https://api.spotify.com/v1/audio-analysis/575N...       201253
# 4     https://api.spotify.com/v1/audio-analysis/76cy...       217947
# ...                                                 ...          ...
# 2523  https://api.spotify.com/v1/audio-analysis/4RCK...       150477
# 2524  https://api.spotify.com/v1/audio-analysis/4RCK...       150477
# 2525  https://api.spotify.com/v1/audio-analysis/2dSN...        94000
# 2526  https://api.spotify.com/v1/audio-analysis/2dSN...        94000
# 2527  https://api.spotify.com/v1/audio-analysis/2dSN...        94000
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2523               4
# 2524               4
# 2525               4
# 2526               4
# 2527               4
#
# [2528 rows x 18 columns]

# %%
play_4 = pd.concat([df_4 , audio4_df], axis=1)

# %% [markdown]
# ### 5th Playlist

# %%
playlist5 = get_playlist_tracks("4rnleEAOdmFAbRcNCgZMpY")

# %%
playlst_5 = list(map(get_name_artist_from_playlist_item,playlist5))

# %%
playlst_5 = flatten(playlst_5)

# %%
# playlst_5

# %%
df_5 = pd.DataFrame(playlst_5)
df_5
# Out:
#                                          0                   1  \
# 0                        Take Me To Church              Hozier
# 1              Cooler Than Me - Single Mix         Mike Posner
# 2              Cooler Than Me - Single Mix            Gigamesh
# 3         See You Again (feat. Kali Uchis)  Tyler, The Creator
# 4         See You Again (feat. Kali Uchis)          Kali Uchis
# ...                                    ...                 ...
# 7722                               deja vu      Olivia Rodrigo
# 7723                     WHOLE LOTTA MONEY                 BIA
# 7724  Slumber Party (feat. Princess Nokia)            Ashnikko
# 7725  Slumber Party (feat. Princess Nokia)      Princess Nokia
# 7726                             telepatía          Kali Uchis
#
#                                          2
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 2     spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 3     spotify:track:7KA4W4McWYRpgf0fWsJZWB
# 4     spotify:track:7KA4W4McWYRpgf0fWsJZWB
# ...                                    ...
# 7722  spotify:track:61KpQadow081I2AsbeLcsb
# 7723  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 7724  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 7725  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 7726  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
#
# [7727 rows x 3 columns]

# %%
audio5 = []

for x in df_5[2]:
    audio5.append(sp.audio_features(x))

# %%
audio5 = flatten(audio5)
audio5_df = pd.DataFrame(audio5)
audio5_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.566   0.664    4    -5.303     0       0.0464       0.63400
# 1            0.768   0.820    7    -4.630     0       0.0474       0.17900
# 2            0.768   0.820    7    -4.630     0       0.0474       0.17900
# 3            0.558   0.559    6    -9.222     1       0.0959       0.37100
# 4            0.558   0.559    6    -9.222     1       0.0959       0.37100
# ...            ...     ...  ...       ...   ...          ...           ...
# 7722         0.439   0.610    9    -7.236     1       0.1160       0.59300
# 7723         0.897   0.371    1    -5.019     1       0.3680       0.09040
# 7724         0.964   0.398   11    -8.981     0       0.0795       0.00151
# 7725         0.964   0.398   11    -8.981     0       0.0795       0.00151
# 7726         0.653   0.524   11    -9.016     0       0.0502       0.11200
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000     0.116    0.437  128.945  audio_features
# 1             0.000000     0.689    0.625  129.965  audio_features
# 2             0.000000     0.689    0.625  129.965  audio_features
# 3             0.000007     0.109    0.620   78.558  audio_features
# 4             0.000007     0.109    0.620   78.558  audio_features
# ...                ...       ...      ...      ...             ...
# 7722          0.000011     0.341    0.172  181.088  audio_features
# 7723          0.000000     0.325    0.441   81.008  audio_features
# 7724          0.000039     0.101    0.563  105.012  audio_features
# 7725          0.000039     0.101    0.563  105.012  audio_features
# 7726          0.000000     0.203    0.553   83.970  audio_features
#
#                           id                                   uri  \
# 0     7dS5EaCoMnN7DzlpT6aRn2  spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# 1     2V4bv1fNWfTcyRJKmej6Sj  spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 2     2V4bv1fNWfTcyRJKmej6Sj  spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 3     7KA4W4McWYRpgf0fWsJZWB  spotify:track:7KA4W4McWYRpgf0fWsJZWB
# 4     7KA4W4McWYRpgf0fWsJZWB  spotify:track:7KA4W4McWYRpgf0fWsJZWB
# ...                      ...                                   ...
# 7722  61KpQadow081I2AsbeLcsb  spotify:track:61KpQadow081I2AsbeLcsb
# 7723  5yorXJWdBan1Vlh116ZtQ7  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 7724  11ZulcYY4lowvcQm4oe3VJ  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 7725  11ZulcYY4lowvcQm4oe3VJ  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 7726  6tDDoYIxWvMLTdKpjFkc1B  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1     https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2     https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 3     https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 4     https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# ...                                                 ...
# 7722  https://api.spotify.com/v1/tracks/61KpQadow081...
# 7723  https://api.spotify.com/v1/tracks/5yorXJWdBan1...
# 7724  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 7725  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 7726  https://api.spotify.com/v1/tracks/6tDDoYIxWvML...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7dS5...       241688
# 1     https://api.spotify.com/v1/audio-analysis/2V4b...       213293
# 2     https://api.spotify.com/v1/audio-analysis/2V4b...       213293
# 3     https://api.spotify.com/v1/audio-analysis/7KA4...       180387
# 4     https://api.spotify.com/v1/audio-analysis/7KA4...       180387
# ...                                                 ...          ...
# 7722  https://api.spotify.com/v1/audio-analysis/61Kp...       215508
# 7723  https://api.spotify.com/v1/audio-analysis/5yor...       156005
# 7724  https://api.spotify.com/v1/audio-analysis/11Zu...       178405
# 7725  https://api.spotify.com/v1/audio-analysis/11Zu...       178405
# 7726  https://api.spotify.com/v1/audio-analysis/6tDD...       160191
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7722               4
# 7723               4
# 7724               4
# 7725               4
# 7726               4
#
# [7727 rows x 18 columns]

# %%
play_5 = pd.concat([df_5 , audio5_df], axis=1)

# %% [markdown]
# ### More playlists

# %% [markdown]
# I will use another notebook to add more playlists as I am running into problems using this one and hope it will help

# %% [markdown]
# ### Putting all playlists together

# %%
all_songs = pd.concat([play_1, play_2,play_3,play_4,play_5], axis=0)

# %%
len(all_songs)
# Out:
# 11228

# %% [markdown]
# I will now remove duplicates and change header names

# %%
all_songs = all_songs.drop_duplicates()

# %%
len(all_songs)
# Out:
# 10320

# %%
all_songs
# Out:
#                                          0                1  \
# 0                     (You Drive Me) Crazy   Britney Spears
# 1                              Barbie Girl             Aqua
# 2                              Coco Jamboo    Mr. President
# 3                             Irresistible  Jessica Simpson
# 4                 Uptown Girl - Radio Edit         Westlife
# ...                                    ...              ...
# 7720                                Freaks       Surf Curse
# 7721                       Hermit the Frog           MARINA
# 7723                     WHOLE LOTTA MONEY              BIA
# 7724  Slumber Party (feat. Princess Nokia)         Ashnikko
# 7725  Slumber Party (feat. Princess Nokia)   Princess Nokia
#
#                                          2  danceability  energy  key  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv         0.748   0.939    0
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr         0.812   0.879    1
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d         0.832   0.838    1
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5         0.657   0.965    8
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH         0.645   0.921    6
# ...                                    ...           ...     ...  ...
# 7720  spotify:track:0HUTL8i4y4MiGCPId7M7wb         0.346   0.944    9
# 7721  spotify:track:4Zcz6saEkOII3PlXd9gN3o         0.609   0.679    0
# 7723  spotify:track:5yorXJWdBan1Vlh116ZtQ7         0.897   0.371    1
# 7724  spotify:track:11ZulcYY4lowvcQm4oe3VJ         0.964   0.398   11
# 7725  spotify:track:11ZulcYY4lowvcQm4oe3VJ         0.964   0.398   11
#
#       loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0       -4.288     0       0.0341      0.053400  ...    0.3200    0.960
# 1      -10.998     0       0.0397      0.016700  ...    0.3660    0.962
# 2       -5.414     0       0.0421      0.079100  ...    0.1520    0.965
# 3       -2.771     0       0.0556      0.028500  ...    0.0552    0.669
# 4       -5.256     0       0.0302      0.008090  ...    0.4070    0.864
# ...        ...   ...          ...           ...  ...       ...      ...
# 7720    -9.874     1       0.0485      0.000042  ...    0.0546    0.403
# 7721    -4.545     1       0.0312      0.243000  ...    0.1990    0.487
# 7723    -5.019     1       0.3680      0.090400  ...    0.3250    0.441
# 7724    -8.981     0       0.0795      0.001510  ...    0.1010    0.563
# 7725    -8.981     0       0.0795      0.001510  ...    0.1010    0.563
#
#         tempo            type                      id  \
# 0     104.001  audio_features  1DSJNBNhGZCigg9ll5VeZv
# 1     129.991  audio_features  5ZrDlcxIDZyjOzHdYW1ydr
# 2     100.021  audio_features  5fRvePkRGdpn2nKacG7I6d
# 3      93.013  audio_features  20NKCc2ag4FT1DLk0C2oT5
# 4     129.000  audio_features  2sFp6E7lNBbblJGmUtCfFH
# ...       ...             ...                     ...
# 7720  179.630  audio_features  0HUTL8i4y4MiGCPId7M7wb
# 7721  122.034  audio_features  4Zcz6saEkOII3PlXd9gN3o
# 7723   81.008  audio_features  5yorXJWdBan1Vlh116ZtQ7
# 7724  105.012  audio_features  11ZulcYY4lowvcQm4oe3VJ
# 7725  105.012  audio_features  11ZulcYY4lowvcQm4oe3VJ
#
#                                        uri  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH
# ...                                    ...
# 7720  spotify:track:0HUTL8i4y4MiGCPId7M7wb
# 7721  spotify:track:4Zcz6saEkOII3PlXd9gN3o
# 7723  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 7724  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 7725  spotify:track:11ZulcYY4lowvcQm4oe3VJ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1DSJNBNhGZCi...
# 1     https://api.spotify.com/v1/tracks/5ZrDlcxIDZyj...
# 2     https://api.spotify.com/v1/tracks/5fRvePkRGdpn...
# 3     https://api.spotify.com/v1/tracks/20NKCc2ag4FT...
# 4     https://api.spotify.com/v1/tracks/2sFp6E7lNBbb...
# ...                                                 ...
# 7720  https://api.spotify.com/v1/tracks/0HUTL8i4y4Mi...
# 7721  https://api.spotify.com/v1/tracks/4Zcz6saEkOII...
# 7723  https://api.spotify.com/v1/tracks/5yorXJWdBan1...
# 7724  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 7725  https://api.spotify.com/v1/tracks/11ZulcYY4low...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1DSJ...      198067
# 1     https://api.spotify.com/v1/audio-analysis/5ZrD...      197960
# 2     https://api.spotify.com/v1/audio-analysis/5fRv...      218733
# 3     https://api.spotify.com/v1/audio-analysis/20NK...      194027
# 4     https://api.spotify.com/v1/audio-analysis/2sFp...      186440
# ...                                                 ...         ...
# 7720  https://api.spotify.com/v1/audio-analysis/0HUT...      147036
# 7721  https://api.spotify.com/v1/audio-analysis/4Zcz...      215960
# 7723  https://api.spotify.com/v1/audio-analysis/5yor...      156005
# 7724  https://api.spotify.com/v1/audio-analysis/11Zu...      178405
# 7725  https://api.spotify.com/v1/audio-analysis/11Zu...      178405
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7720               4
# 7721               4
# 7723               4
# 7724               4
# 7725               4
#
# [10320 rows x 21 columns]

# %%
all_songs = all_songs.drop_duplicates(subset=[0, 2],keep='first')

# %%
all_songs.reset_index(drop=True)
# Out:
#                                          0                1  \
# 0                     (You Drive Me) Crazy   Britney Spears
# 1                              Barbie Girl             Aqua
# 2                              Coco Jamboo    Mr. President
# 3                             Irresistible  Jessica Simpson
# 4                 Uptown Girl - Radio Edit         Westlife
# ...                                    ...              ...
# 7228                                 Venom      Little Simz
# 7229                                Freaks       Surf Curse
# 7230                       Hermit the Frog           MARINA
# 7231                     WHOLE LOTTA MONEY              BIA
# 7232  Slumber Party (feat. Princess Nokia)         Ashnikko
#
#                                          2  danceability  energy  key  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv         0.748   0.939    0
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr         0.812   0.879    1
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d         0.832   0.838    1
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5         0.657   0.965    8
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH         0.645   0.921    6
# ...                                    ...           ...     ...  ...
# 7228  spotify:track:3A0ITFj6kbb9CggwtPe55f         0.436   0.655    7
# 7229  spotify:track:0HUTL8i4y4MiGCPId7M7wb         0.346   0.944    9
# 7230  spotify:track:4Zcz6saEkOII3PlXd9gN3o         0.609   0.679    0
# 7231  spotify:track:5yorXJWdBan1Vlh116ZtQ7         0.897   0.371    1
# 7232  spotify:track:11ZulcYY4lowvcQm4oe3VJ         0.964   0.398   11
#
#       loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0       -4.288     0       0.0341      0.053400  ...    0.3200    0.960
# 1      -10.998     0       0.0397      0.016700  ...    0.3660    0.962
# 2       -5.414     0       0.0421      0.079100  ...    0.1520    0.965
# 3       -2.771     0       0.0556      0.028500  ...    0.0552    0.669
# 4       -5.256     0       0.0302      0.008090  ...    0.4070    0.864
# ...        ...   ...          ...           ...  ...       ...      ...
# 7228    -8.153     1       0.1590      0.425000  ...    0.3930    0.523
# 7229    -9.874     1       0.0485      0.000042  ...    0.0546    0.403
# 7230    -4.545     1       0.0312      0.243000  ...    0.1990    0.487
# 7231    -5.019     1       0.3680      0.090400  ...    0.3250    0.441
# 7232    -8.981     0       0.0795      0.001510  ...    0.1010    0.563
#
#         tempo            type                      id  \
# 0     104.001  audio_features  1DSJNBNhGZCigg9ll5VeZv
# 1     129.991  audio_features  5ZrDlcxIDZyjOzHdYW1ydr
# 2     100.021  audio_features  5fRvePkRGdpn2nKacG7I6d
# 3      93.013  audio_features  20NKCc2ag4FT1DLk0C2oT5
# 4     129.000  audio_features  2sFp6E7lNBbblJGmUtCfFH
# ...       ...             ...                     ...
# 7228  139.712  audio_features  3A0ITFj6kbb9CggwtPe55f
# 7229  179.630  audio_features  0HUTL8i4y4MiGCPId7M7wb
# 7230  122.034  audio_features  4Zcz6saEkOII3PlXd9gN3o
# 7231   81.008  audio_features  5yorXJWdBan1Vlh116ZtQ7
# 7232  105.012  audio_features  11ZulcYY4lowvcQm4oe3VJ
#
#                                        uri  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH
# ...                                    ...
# 7228  spotify:track:3A0ITFj6kbb9CggwtPe55f
# 7229  spotify:track:0HUTL8i4y4MiGCPId7M7wb
# 7230  spotify:track:4Zcz6saEkOII3PlXd9gN3o
# 7231  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 7232  spotify:track:11ZulcYY4lowvcQm4oe3VJ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1DSJNBNhGZCi...
# 1     https://api.spotify.com/v1/tracks/5ZrDlcxIDZyj...
# 2     https://api.spotify.com/v1/tracks/5fRvePkRGdpn...
# 3     https://api.spotify.com/v1/tracks/20NKCc2ag4FT...
# 4     https://api.spotify.com/v1/tracks/2sFp6E7lNBbb...
# ...                                                 ...
# 7228  https://api.spotify.com/v1/tracks/3A0ITFj6kbb9...
# 7229  https://api.spotify.com/v1/tracks/0HUTL8i4y4Mi...
# 7230  https://api.spotify.com/v1/tracks/4Zcz6saEkOII...
# 7231  https://api.spotify.com/v1/tracks/5yorXJWdBan1...
# 7232  https://api.spotify.com/v1/tracks/11ZulcYY4low...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1DSJ...      198067
# 1     https://api.spotify.com/v1/audio-analysis/5ZrD...      197960
# 2     https://api.spotify.com/v1/audio-analysis/5fRv...      218733
# 3     https://api.spotify.com/v1/audio-analysis/20NK...      194027
# 4     https://api.spotify.com/v1/audio-analysis/2sFp...      186440
# ...                                                 ...         ...
# 7228  https://api.spotify.com/v1/audio-analysis/3A0I...      154749
# 7229  https://api.spotify.com/v1/audio-analysis/0HUT...      147036
# 7230  https://api.spotify.com/v1/audio-analysis/4Zcz...      215960
# 7231  https://api.spotify.com/v1/audio-analysis/5yor...      156005
# 7232  https://api.spotify.com/v1/audio-analysis/11Zu...      178405
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7228               4
# 7229               4
# 7230               4
# 7231               4
# 7232               4
#
# [7233 rows x 21 columns]

# %%
all_songs = all_songs.rename(columns={0:'song', 1:'singer', 2:'uri'})

# %%
all_songs
# Out:
#                                       song           singer  \
# 0                     (You Drive Me) Crazy   Britney Spears
# 1                              Barbie Girl             Aqua
# 2                              Coco Jamboo    Mr. President
# 3                             Irresistible  Jessica Simpson
# 4                 Uptown Girl - Radio Edit         Westlife
# ...                                    ...              ...
# 7719                                 Venom      Little Simz
# 7720                                Freaks       Surf Curse
# 7721                       Hermit the Frog           MARINA
# 7723                     WHOLE LOTTA MONEY              BIA
# 7724  Slumber Party (feat. Princess Nokia)         Ashnikko
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv         0.748   0.939    0
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr         0.812   0.879    1
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d         0.832   0.838    1
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5         0.657   0.965    8
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH         0.645   0.921    6
# ...                                    ...           ...     ...  ...
# 7719  spotify:track:3A0ITFj6kbb9CggwtPe55f         0.436   0.655    7
# 7720  spotify:track:0HUTL8i4y4MiGCPId7M7wb         0.346   0.944    9
# 7721  spotify:track:4Zcz6saEkOII3PlXd9gN3o         0.609   0.679    0
# 7723  spotify:track:5yorXJWdBan1Vlh116ZtQ7         0.897   0.371    1
# 7724  spotify:track:11ZulcYY4lowvcQm4oe3VJ         0.964   0.398   11
#
#       loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0       -4.288     0       0.0341      0.053400  ...    0.3200    0.960
# 1      -10.998     0       0.0397      0.016700  ...    0.3660    0.962
# 2       -5.414     0       0.0421      0.079100  ...    0.1520    0.965
# 3       -2.771     0       0.0556      0.028500  ...    0.0552    0.669
# 4       -5.256     0       0.0302      0.008090  ...    0.4070    0.864
# ...        ...   ...          ...           ...  ...       ...      ...
# 7719    -8.153     1       0.1590      0.425000  ...    0.3930    0.523
# 7720    -9.874     1       0.0485      0.000042  ...    0.0546    0.403
# 7721    -4.545     1       0.0312      0.243000  ...    0.1990    0.487
# 7723    -5.019     1       0.3680      0.090400  ...    0.3250    0.441
# 7724    -8.981     0       0.0795      0.001510  ...    0.1010    0.563
#
#         tempo            type                      id  \
# 0     104.001  audio_features  1DSJNBNhGZCigg9ll5VeZv
# 1     129.991  audio_features  5ZrDlcxIDZyjOzHdYW1ydr
# 2     100.021  audio_features  5fRvePkRGdpn2nKacG7I6d
# 3      93.013  audio_features  20NKCc2ag4FT1DLk0C2oT5
# 4     129.000  audio_features  2sFp6E7lNBbblJGmUtCfFH
# ...       ...             ...                     ...
# 7719  139.712  audio_features  3A0ITFj6kbb9CggwtPe55f
# 7720  179.630  audio_features  0HUTL8i4y4MiGCPId7M7wb
# 7721  122.034  audio_features  4Zcz6saEkOII3PlXd9gN3o
# 7723   81.008  audio_features  5yorXJWdBan1Vlh116ZtQ7
# 7724  105.012  audio_features  11ZulcYY4lowvcQm4oe3VJ
#
#                                        uri  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH
# ...                                    ...
# 7719  spotify:track:3A0ITFj6kbb9CggwtPe55f
# 7720  spotify:track:0HUTL8i4y4MiGCPId7M7wb
# 7721  spotify:track:4Zcz6saEkOII3PlXd9gN3o
# 7723  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 7724  spotify:track:11ZulcYY4lowvcQm4oe3VJ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1DSJNBNhGZCi...
# 1     https://api.spotify.com/v1/tracks/5ZrDlcxIDZyj...
# 2     https://api.spotify.com/v1/tracks/5fRvePkRGdpn...
# 3     https://api.spotify.com/v1/tracks/20NKCc2ag4FT...
# 4     https://api.spotify.com/v1/tracks/2sFp6E7lNBbb...
# ...                                                 ...
# 7719  https://api.spotify.com/v1/tracks/3A0ITFj6kbb9...
# 7720  https://api.spotify.com/v1/tracks/0HUTL8i4y4Mi...
# 7721  https://api.spotify.com/v1/tracks/4Zcz6saEkOII...
# 7723  https://api.spotify.com/v1/tracks/5yorXJWdBan1...
# 7724  https://api.spotify.com/v1/tracks/11ZulcYY4low...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1DSJ...      198067
# 1     https://api.spotify.com/v1/audio-analysis/5ZrD...      197960
# 2     https://api.spotify.com/v1/audio-analysis/5fRv...      218733
# 3     https://api.spotify.com/v1/audio-analysis/20NK...      194027
# 4     https://api.spotify.com/v1/audio-analysis/2sFp...      186440
# ...                                                 ...         ...
# 7719  https://api.spotify.com/v1/audio-analysis/3A0I...      154749
# 7720  https://api.spotify.com/v1/audio-analysis/0HUT...      147036
# 7721  https://api.spotify.com/v1/audio-analysis/4Zcz...      215960
# 7723  https://api.spotify.com/v1/audio-analysis/5yor...      156005
# 7724  https://api.spotify.com/v1/audio-analysis/11Zu...      178405
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7719               4
# 7720               4
# 7721               4
# 7723               4
# 7724               4
#
# [7233 rows x 21 columns]

# %% [markdown]
# I will now save my data in a csv file

# %%
all_songs.to_csv('all_songs.csv', index=False)

# %% [markdown]
# Concatenating this and the DF from the other file and clean up duplicates

# %%
all_songs = pd.read_csv('all_songs.csv')
all_songs2 = pd.read_csv('all_songs2.csv')

# %%
all_songs = pd.concat([all_songs, all_songs2], axis=0)

# %%
all_songs
# Out:
#                                 song             singer  \
# 0               (You Drive Me) Crazy     Britney Spears
# 1                        Barbie Girl               Aqua
# 2                        Coco Jamboo      Mr. President
# 3                       Irresistible    Jessica Simpson
# 4           Uptown Girl - Radio Edit           Westlife
# ...                              ...                ...
# 3666  Let's Stay Together - Acoustic       Grace George
# 3667             Meet Me At Our Spot        The Mayries
# 3668               I Will Follow You           Toulouse
# 3669          Tiny Dancer (Acoustic)  The Moon Loungers
# 3670                     Stand By Me       Marco Foster
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv         0.748   0.939    0
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr         0.812   0.879    1
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d         0.832   0.838    1
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5         0.657   0.965    8
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH         0.645   0.921    6
# ...                                    ...           ...     ...  ...
# 3666  spotify:track:0zSnkrmyhU49EkTojA5gRm         0.665   0.186    4
# 3667  spotify:track:6C59fCVU93fBCY6pDe5Euc         0.396   0.306    2
# 3668  spotify:track:5YIEsBBvaFfyHAppVoaEcm         0.439   0.144    8
# 3669  spotify:track:0OgukDucI2L5KRv9hWyooZ         0.619   0.357    7
# 3670  spotify:track:2WKCc1aAqw51V9qClDkHde         0.685   0.206    5
#
#       loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0       -4.288     0       0.0341       0.05340  ...    0.3200    0.960
# 1      -10.998     0       0.0397       0.01670  ...    0.3660    0.962
# 2       -5.414     0       0.0421       0.07910  ...    0.1520    0.965
# 3       -2.771     0       0.0556       0.02850  ...    0.0552    0.669
# 4       -5.256     0       0.0302       0.00809  ...    0.4070    0.864
# ...        ...   ...          ...           ...  ...       ...      ...
# 3666   -10.151     0       0.0290       0.90200  ...    0.1050    0.372
# 3667    -9.961     1       0.0341       0.90600  ...    0.2460    0.309
# 3668   -17.701     1       0.0346       0.84100  ...    0.1870    0.246
# 3669    -9.166     1       0.0289       0.85900  ...    0.1130    0.457
# 3670   -10.209     1       0.0411       0.93600  ...    0.1050    0.375
#
#         tempo            type                      id  \
# 0     104.001  audio_features  1DSJNBNhGZCigg9ll5VeZv
# 1     129.991  audio_features  5ZrDlcxIDZyjOzHdYW1ydr
# 2     100.021  audio_features  5fRvePkRGdpn2nKacG7I6d
# 3      93.013  audio_features  20NKCc2ag4FT1DLk0C2oT5
# 4     129.000  audio_features  2sFp6E7lNBbblJGmUtCfFH
# ...       ...             ...                     ...
# 3666   82.046  audio_features  0zSnkrmyhU49EkTojA5gRm
# 3667  179.222  audio_features  6C59fCVU93fBCY6pDe5Euc
# 3668   80.445  audio_features  5YIEsBBvaFfyHAppVoaEcm
# 3669  125.977  audio_features  0OgukDucI2L5KRv9hWyooZ
# 3670  114.660  audio_features  2WKCc1aAqw51V9qClDkHde
#
#                                      uri.1  \
# 0     spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 1     spotify:track:5ZrDlcxIDZyjOzHdYW1ydr
# 2     spotify:track:5fRvePkRGdpn2nKacG7I6d
# 3     spotify:track:20NKCc2ag4FT1DLk0C2oT5
# 4     spotify:track:2sFp6E7lNBbblJGmUtCfFH
# ...                                    ...
# 3666  spotify:track:0zSnkrmyhU49EkTojA5gRm
# 3667  spotify:track:6C59fCVU93fBCY6pDe5Euc
# 3668  spotify:track:5YIEsBBvaFfyHAppVoaEcm
# 3669  spotify:track:0OgukDucI2L5KRv9hWyooZ
# 3670  spotify:track:2WKCc1aAqw51V9qClDkHde
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1DSJNBNhGZCi...
# 1     https://api.spotify.com/v1/tracks/5ZrDlcxIDZyj...
# 2     https://api.spotify.com/v1/tracks/5fRvePkRGdpn...
# 3     https://api.spotify.com/v1/tracks/20NKCc2ag4FT...
# 4     https://api.spotify.com/v1/tracks/2sFp6E7lNBbb...
# ...                                                 ...
# 3666  https://api.spotify.com/v1/tracks/0zSnkrmyhU49...
# 3667  https://api.spotify.com/v1/tracks/6C59fCVU93fB...
# 3668  https://api.spotify.com/v1/tracks/5YIEsBBvaFfy...
# 3669  https://api.spotify.com/v1/tracks/0OgukDucI2L5...
# 3670  https://api.spotify.com/v1/tracks/2WKCc1aAqw51...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1DSJ...      198067
# 1     https://api.spotify.com/v1/audio-analysis/5ZrD...      197960
# 2     https://api.spotify.com/v1/audio-analysis/5fRv...      218733
# 3     https://api.spotify.com/v1/audio-analysis/20NK...      194027
# 4     https://api.spotify.com/v1/audio-analysis/2sFp...      186440
# ...                                                 ...         ...
# 3666  https://api.spotify.com/v1/audio-analysis/0zSn...      231402
# 3667  https://api.spotify.com/v1/audio-analysis/6C59...      157821
# 3668  https://api.spotify.com/v1/audio-analysis/5YIE...      159440
# 3669  https://api.spotify.com/v1/audio-analysis/0Ogu...      430784
# 3670  https://api.spotify.com/v1/audio-analysis/2WKC...      156130
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3666               4
# 3667               4
# 3668               4
# 3669               4
# 3670               4
#
# [10904 rows x 21 columns]

# %%
all_songs = all_songs.drop_duplicates(subset=['song', 'uri'],keep='first')

# %%
len(all_songs)
# Out:
# 10484

# %% [markdown]
# # Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.cluster import KMeans

# %% [markdown]
# First I will get the numeric data and will normalize it

# %%
X_num = all_songs.select_dtypes(include = np.number)
X_num
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.748   0.939    0    -4.288     0       0.0341       0.05340
# 1            0.812   0.879    1   -10.998     0       0.0397       0.01670
# 2            0.832   0.838    1    -5.414     0       0.0421       0.07910
# 3            0.657   0.965    8    -2.771     0       0.0556       0.02850
# 4            0.645   0.921    6    -5.256     0       0.0302       0.00809
# ...            ...     ...  ...       ...   ...          ...           ...
# 3666         0.665   0.186    4   -10.151     0       0.0290       0.90200
# 3667         0.396   0.306    2    -9.961     1       0.0341       0.90600
# 3668         0.439   0.144    8   -17.701     1       0.0346       0.84100
# 3669         0.619   0.357    7    -9.166     1       0.0289       0.85900
# 3670         0.685   0.206    5   -10.209     1       0.0411       0.93600
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.3200    0.960  104.001       198067
# 1             0.224000    0.3660    0.962  129.991       197960
# 2             0.000000    0.1520    0.965  100.021       218733
# 3             0.000088    0.0552    0.669   93.013       194027
# 4             0.000011    0.4070    0.864  129.000       186440
# ...                ...       ...      ...      ...          ...
# 3666          0.000001    0.1050    0.372   82.046       231402
# 3667          0.000000    0.2460    0.309  179.222       157821
# 3668          0.000006    0.1870    0.246   80.445       159440
# 3669          0.000978    0.1130    0.457  125.977       430784
# 3670          0.000024    0.1050    0.375  114.660       156130
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3666               4
# 3667               4
# 3668               4
# 3669               4
# 3670               4
#
# [10484 rows x 13 columns]

# %%
X_prep = StandardScaler().fit_transform(X_num)
pd.DataFrame(X_prep,columns=X_num.columns).head()
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      0.810272  1.354205 -1.451665  0.864097 -1.244834    -0.577252
# 1      1.251392  1.047521 -1.175423 -1.369648 -1.244834    -0.508402
# 2      1.389241  0.837953 -1.175423  0.489254 -1.244834    -0.478895
# 3      0.183056  1.487101  0.758268  1.369104 -1.244834    -0.312918
# 4      0.100346  1.262199  0.205785  0.541852 -1.244834    -0.625200
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.606502         -0.227953  0.814510  1.759853 -0.677906    -0.371882
# 1     -0.750405          1.601717  1.104657  1.768257  0.309450    -0.373914
# 2     -0.505730         -0.227953 -0.245156  1.780863 -0.829106     0.020555
# 3     -0.704136         -0.227231 -0.855726  0.537026 -1.095339    -0.448600
# 4     -0.784165         -0.227865  1.363266  1.356446  0.271802    -0.592674
#
#    time_signature
# 0        0.131768
# 1        0.131768
# 2        0.131768
# 3        0.131768
# 4        0.131768

# %% [markdown]
# Choosing k - Inertia

# %%
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# Choosing k - Silhouette

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
# I don't have a clear elbow with the Inertia but looking at both scores I would think the best number for k is 6

# %%
kmeans1 = KMeans(n_clusters=6)
kmeans1.fit(X_prep)
# Out:
# KMeans(n_clusters=6)

# %%
clusters = kmeans1.predict(X_prep)
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    3159
# 1    1828
# 2    1518
# 3    2786
# 4     879
# 5     314
# dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:,6], c=clusters,alpha=0.5)
plt.show()
